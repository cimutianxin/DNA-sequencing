# %%
import pyabf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
import ruptures as rpt
from statsmodels.graphics.tsaplots import plot_acf
from scipy.signal import periodogram

import level_finder as lf
import data_visualization as dv
import level_category as lc
import data_preprocess as dp

# %% [markdown]
# ...

# %%
abf_24815002 = pyabf.ABF("inputs/24815002.abf")

# %%
abf_24815002=lf.downsample(abf_24815002, 100)
arr_24815002= dp.abf2arr(abf_24815002)

# %%
fig=dv.plot_abf(abf_24815002)

# %%
len(arr_24815002)
# Out:
# 498073

# %%
i_ranges, t_ranges = lf.find_events_arr(arr_24815002)
print(t_ranges)
# Out:
# [(424.079, 427.609)]

# %%
fig = dv.plot_arr(arr_24815002[423079: 428609])

# %%
fig = dv.plot_arr(arr_24815002[i_ranges[0][0] : i_ranges[0][1]])

# %%
list = lf.find_change_points(arr_24815002[i_ranges[0][0] : i_ranges[0][1]])
# Out:
# Searching in range [3511, 3523]: 100%|██████████| 3/3 [00:00<00:00, 26379.27it/s]

# %%
lvls = lf.calc_level4arr(arr_24815002[i_ranges[0][0] : i_ranges[0][1]], list)

# %%
fig = dv.step_arr_lvls(arr_24815002[i_ranges[0][0] : i_ranges[0][1]], lvls)

# %%
len(list)
# Out:
# 513
